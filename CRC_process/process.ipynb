# %%
import os 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import cv2

# %%
root = '/data1/CRC_K/CRC-VAL-HE-7K'
classes_list = os.listdir(root)
classes_list
# Out:
# ['NORM', 'MUC', 'TUM', 'BACK', 'MUS', 'LYM', 'DEB', 'STR', 'ADI']

# %%
def all_path(dirname, file_type):
    result = []
    for maindir, subdir, file_name_list in os.walk(dirname):
        for filename in file_name_list:
            apath = os.path.join(maindir, filename)
            if file_type in apath[-4:]:
                result.append(apath)
    return result

# %%
file_list = all_path(root, '.tif')
print(len(file_list))
file_list[0]
# Out:
# 7180
# '/data1/CRC_K/CRC-VAL-HE-7K/NORM/NORM-TCGA-MPRIWFHW.tif'

# %%
im = cv2.imread(file_list[0])
plt.imshow(im)
plt.show()
