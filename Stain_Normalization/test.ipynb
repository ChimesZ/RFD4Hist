# %%
from process_all import *
import stain_utils as utils
import matplotlib.pyplot as plt
import os
import cv2 
from pathlib import Path

# %%
path = '/data1/GAP/Dataset_10000_5/train/LE/W10-1-1-C.1.01_(9900,8550).jpg'
im = cv2.imread(path)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im_origin = cv2.imread(path.replace('_5', '_5_Norm'))
im_origin = cv2.cvtColor(im_origin, cv2.COLOR_BGR2RGB)
plt.subplot(121)
plt.imshow(im)
plt.subplot(122)
plt.imshow(im_origin)
plt.show()

# %%
im = cv2.imread('/data1/GAP/Dataset_10000_5/train/CTmvp/W10-1-1-F.1.02_(10800,1800).jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im)
plt.show()
